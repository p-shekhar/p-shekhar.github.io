# %% [markdown]
# # 17. Fairness, Bias, and Heterogeneous AI Effects
#
# Draft lecture notebook.
#
# This notebook will estimate heterogeneous effects of AI systems and connect treatment-effect variation to fairness, disparate impact, and subgroup harm.

# %% [markdown]
# ## Planned Coverage
#
# - Treatment effects by subgroup and context.
# - Fairness guardrails and harm metrics.
# - Disparate impact versus heterogeneous benefit.
# - Causal evidence for responsible AI reviews.
