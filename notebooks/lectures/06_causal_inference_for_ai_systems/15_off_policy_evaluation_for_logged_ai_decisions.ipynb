# %% [markdown]
# # 15. Off-Policy Evaluation for Logged AI Decisions
#
# Draft lecture notebook.
#
# This notebook will evaluate logged decisions from AI routing, recommendation, search, support triage, automation, and ranking policies.

# %% [markdown]
# ## Planned Coverage
#
# - Logged propensities and behavior policies.
# - Inverse propensity scoring, self-normalization, and doubly robust OPE.
# - Support and overlap in logged AI decisions.
# - Practical diagnostics for counterfactual policy evaluation.
