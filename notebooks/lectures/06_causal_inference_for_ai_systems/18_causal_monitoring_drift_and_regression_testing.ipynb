# %% [markdown]
# # 18. Causal Monitoring, Drift, and Regression Testing
#
# Draft lecture notebook.
#
# This notebook will monitor AI deployments for causal degradation, drift, model regressions, and changing treatment effects over time.

# %% [markdown]
# ## Planned Coverage
#
# - Monitoring beyond offline evaluation metrics.
# - Drift in populations, treatment effects, outcomes, and exposure.
# - Regression testing for prompts, models, agents, and retrieval systems.
# - Alerting and governance workflows for causal degradation.
