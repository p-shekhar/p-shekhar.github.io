# %% [markdown]
# # 02. From Model Metrics to Causal Impact
#
# Draft lecture notebook.
#
# This notebook will separate offline model performance from real-world causal impact and show why benchmark gains do not automatically imply business, user, or safety improvements.

# %% [markdown]
# ## Planned Coverage
#
# - Accuracy, AUC, eval score, and benchmark performance versus causal impact.
# - Surrogate metrics and when they break.
# - Behavioral responses to AI systems.
# - Translating model improvements into testable causal hypotheses.
