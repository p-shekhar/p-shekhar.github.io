# %% [markdown]
# # 01. AI Systems as Interventions
#
# Draft lecture notebook.
#
# This notebook will frame models, copilots, agents, routing rules, retrieval systems, and human-AI workflows as interventions that change user behavior, worker behavior, downstream data, and business outcomes.

# %% [markdown]
# ## Planned Coverage
#
# - AI deployment as a treatment rather than only a model release.
# - Units, exposure, outcomes, timing, and interference in AI products.
# - Examples from copilots, support automation, ranking, RAG, and routing.
# - Why causal estimands are needed before interpreting impact.
