# %% [markdown]
# # 06. Human-AI Workflows and Post-Treatment Variables
#
# Draft lecture notebook.
#
# This notebook will examine human override, acceptance, usage, retrieval success, escalation, and handoff as variables that often happen after treatment assignment.

# %% [markdown]
# ## Planned Coverage
#
# - Human-AI workflows as causal systems.
# - Post-treatment variables and bad controls.
# - Mediation versus adjustment mistakes.
# - Examples from copilots, triage, support, and decision automation.
