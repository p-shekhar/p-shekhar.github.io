# %% [markdown]
# # 05. Triggered Experiments and Exposure Logging
#
# Draft lecture notebook.
#
# This notebook will study AI experiments where assigned users are not always exposed, making triggering, eligibility, exposure, and usage logs central to valid interpretation.

# %% [markdown]
# ## Planned Coverage
#
# - Assignment versus exposure in AI products.
# - Triggered analyses and their risks.
# - Exposure logging schemas for AI systems.
# - ITT, treatment-on-treated, and principal-stratum intuition.
