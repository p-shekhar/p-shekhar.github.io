# %% [markdown]
# # 03. Estimands for AI Product Changes
#
# Draft lecture notebook.
#
# This notebook will define estimands for AI deployments by making the treatment, unit, outcome, exposure, triggering rule, time window, and target population explicit.

# %% [markdown]
# ## Planned Coverage
#
# - Treatment definitions for models, prompts, workflows, and routing policies.
# - Assignment, exposure, triggering, and compliance.
# - Outcomes and guardrails for AI features.
# - Estimand templates for product and enterprise AI changes.
