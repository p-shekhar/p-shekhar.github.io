# %% [markdown]
# # 22. Capstone: Evaluating an AI System End to End
#
# Draft lecture notebook.
#
# This notebook will complete a full causal evaluation of an AI system: define the estimand, design logs, choose a method, estimate impact, diagnose risks, and write a deployment memo.

# %% [markdown]
# ## Planned Coverage
#
# - End-to-end AI system evaluation workflow.
# - Estimand, logging, design, estimation, diagnostics, and sensitivity analysis.
# - Guardrails, governance, and decision analysis.
# - Portfolio-ready deployment memo.
