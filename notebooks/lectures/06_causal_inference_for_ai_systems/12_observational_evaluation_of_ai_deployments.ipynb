# %% [markdown]
# # 12. Observational Evaluation of AI Deployments
#
# Draft lecture notebook.
#
# This notebook will use regression adjustment, propensity scores, doubly robust estimators, and sensitivity analysis for non-randomized AI launches.

# %% [markdown]
# ## Planned Coverage
#
# - When AI deployment is not randomized.
# - Confounders, overlap, and treatment assignment mechanisms.
# - Regression, weighting, matching, and doubly robust estimation.
# - Sensitivity analysis and credibility assessment.
