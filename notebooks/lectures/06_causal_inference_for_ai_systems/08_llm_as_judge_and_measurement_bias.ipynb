# %% [markdown]
# # 08. LLM-as-Judge and Measurement Bias
#
# Draft lecture notebook.
#
# This notebook will treat AI evaluators as noisy measurement systems and show how measurement bias can distort causal conclusions about AI product changes.

# %% [markdown]
# ## Planned Coverage
#
# - LLM judges as outcome measurement tools.
# - Calibration with human audit labels.
# - Differential measurement error by treatment arm or subgroup.
# - Evaluation designs that separate real improvement from judging artifacts.
