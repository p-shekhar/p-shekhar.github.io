# %% [markdown]
# # 11. Policy Changes, Routing, and Selection Bias
#
# Draft lecture notebook.
#
# This notebook will show how AI systems route cases selectively, creating confounding and selection bias when evaluating deployed policies.

# %% [markdown]
# ## Planned Coverage
#
# - Routing policies as assignment mechanisms.
# - Selection into AI handling, human review, and escalation.
# - Confounding from risk scores, queues, and priority rules.
# - Design and logging practices that preserve evaluation options.
