# %% [markdown]
# # 04. Randomized Experiments for AI Features
#
# Draft lecture notebook.
#
# This notebook will cover A/B tests for AI features, model upgrades, copilots, ranking models, workflow automation, and AI-assisted decision systems.

# %% [markdown]
# ## Planned Coverage
#
# - Randomization units for AI products.
# - Treatment assignment for model, prompt, UI, and workflow changes.
# - Power, guardrails, rollout plans, and stopping rules.
# - Interpreting intent-to-treat effects for AI deployments.
