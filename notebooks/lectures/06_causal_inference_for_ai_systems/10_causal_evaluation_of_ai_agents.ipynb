# %% [markdown]
# # 10. Causal Evaluation of AI Agents
#
# Draft lecture notebook.
#
# This notebook will evaluate agents as multi-step interventions involving tool use, memory, planning, routing, autonomy level, and human handoff.

# %% [markdown]
# ## Planned Coverage
#
# - Agent architecture changes as treatments.
# - Multi-step actions, intermediate states, and outcome timing.
# - Safety, escalation, and cost guardrails.
# - Evaluation designs for agent workflows.
