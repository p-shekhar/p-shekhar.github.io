# %% [markdown]
# # 16. Interference and Feedback Loops in AI Systems
#
# Draft lecture notebook.
#
# This notebook will study how AI output affects users, workers, future data, future model behavior, and other users in the same ecosystem.

# %% [markdown]
# ## Planned Coverage
#
# - Violations of no-interference in AI products.
# - Marketplace, social, support, and enterprise spillovers.
# - Feedback loops between deployment, behavior, labels, and retraining.
# - Design strategies for measuring effects in dynamic systems.
