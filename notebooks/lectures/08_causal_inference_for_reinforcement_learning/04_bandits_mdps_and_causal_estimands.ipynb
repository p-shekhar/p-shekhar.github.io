# %% [markdown]
# # 04. Bandits, MDPs, and Causal Estimands
#
# Draft lecture notebook.
#
# This notebook will introduce contextual bandits, Markov decision processes, policies, value functions, and causal estimands for sequential decision systems.

# %% [markdown]
# ## Planned Coverage
#
# - Contextual bandits versus MDPs.
# - Policy value as a causal estimand.
# - Rewards, long-run outcomes, and discounting.
# - Examples where bandit logic is enough and where full RL is needed.
