# %% [markdown]
# # 14. Time-Varying Confounding and Marginal Structural Models
#
# Draft lecture notebook.
#
# This notebook will study time-varying confounders affected by prior actions and use marginal structural models for longitudinal policy effects.

# %% [markdown]
# ## Planned Coverage
#
# - Time-varying confounding affected by prior treatment.
# - Why ordinary regression adjustment can fail.
# - Stabilized inverse probability weights.
# - Marginal structural models for sequential decisions.
