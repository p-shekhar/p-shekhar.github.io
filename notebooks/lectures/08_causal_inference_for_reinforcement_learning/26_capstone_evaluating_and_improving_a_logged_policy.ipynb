# %% [markdown]
# # 26. Capstone: Evaluating and Improving a Logged Policy
#
# Draft lecture notebook.
#
# This notebook will complete an end-to-end project: logged data audit, estimand, off-policy evaluation, diagnostics, safe policy improvement, and decision memo.

# %% [markdown]
# ## Planned Coverage
#
# - Logged policy audit and causal estimand definition.
# - OPE with diagnostics and sensitivity checks.
# - Safe policy improvement recommendation.
# - Portfolio-ready technical and executive memo.
