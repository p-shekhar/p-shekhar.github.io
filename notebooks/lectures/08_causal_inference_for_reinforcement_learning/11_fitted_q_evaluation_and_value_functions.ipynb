# %% [markdown]
# # 11. Fitted Q Evaluation and Value Functions
#
# Draft lecture notebook.
#
# This notebook will introduce value functions and fitted Q evaluation as a way to estimate policy value in sequential settings.

# %% [markdown]
# ## Planned Coverage
#
# - State-value and action-value functions.
# - Bellman-style reasoning for causal learners.
# - Fitted Q evaluation from logged trajectories.
# - Diagnostics for value-function estimation.
