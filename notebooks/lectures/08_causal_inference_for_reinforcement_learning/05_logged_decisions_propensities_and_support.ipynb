# %% [markdown]
# # 05. Logged Decisions, Propensities, and Support
#
# Draft lecture notebook.
#
# This notebook will explain logged decision data, behavior policies, action propensities, support, overlap, and why historical logs can or cannot identify a new policy's value.

# %% [markdown]
# ## Planned Coverage
#
# - Logged actions, contexts, rewards, and propensities.
# - Behavior policy versus target policy.
# - Support and overlap for policy evaluation.
# - Practical logging requirements for causal RL.
