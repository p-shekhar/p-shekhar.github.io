# %% [markdown]
# # 21. Heterogeneous Policy Effects and Personalization
#
# Draft lecture notebook.
#
# This notebook will examine which users benefit from which policy and connect individualized treatment rules to personalization in sequential decision systems.

# %% [markdown]
# ## Planned Coverage
#
# - Heterogeneous policy effects.
# - Individualized treatment rules and personalization.
# - Subgroup policy value and fairness.
# - Targeting decisions under uncertainty.
