# %% [markdown]
# # 23. RLHF, Preference Optimization, and Causal Questions
#
# Draft lecture notebook.
#
# This notebook will introduce RLHF, preference data, reward models, policy optimization, and the causal questions that arise when training LLMs from human feedback.

# %% [markdown]
# ## Planned Coverage
#
# - RLHF and preference optimization at a conceptual level.
# - Preference data as noisy, selected, heterogeneous feedback.
# - Reward models as learned measurement systems.
# - Reward hacking, Goodhart effects, and alignment interventions.
