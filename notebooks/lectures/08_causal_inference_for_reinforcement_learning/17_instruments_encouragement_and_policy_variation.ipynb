# %% [markdown]
# # 17. Instruments, Encouragement, and Policy Variation
#
# Draft lecture notebook.
#
# This notebook will use encouragement, randomized nudges, natural policy variation, and instruments to identify effects in sequential decision settings.

# %% [markdown]
# ## Planned Coverage
#
# - Encouragement designs for policy exposure.
# - Instrumental variation in sequential systems.
# - Compliance, exclusion restrictions, and monotonicity.
# - Practical examples from recommendations, triage, and operations.
