# %% [markdown]
# # 19. Reward Design, Proxy Outcomes, and Goodhart Effects
#
# Draft lecture notebook.
#
# This notebook will study reward misspecification, proxy outcomes, Goodhart effects, and causal outcome design for sequential policies.

# %% [markdown]
# ## Planned Coverage
#
# - Reward design as outcome design.
# - Proxy metrics and long-run harms.
# - Goodhart effects under policy optimization.
# - Guardrails and multi-objective evaluation.
