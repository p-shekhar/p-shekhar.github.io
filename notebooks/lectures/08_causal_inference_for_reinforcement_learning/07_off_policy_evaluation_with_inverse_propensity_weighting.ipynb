# %% [markdown]
# # 07. Off-Policy Evaluation with Inverse Propensity Weighting
#
# Draft lecture notebook.
#
# This notebook will introduce inverse propensity scoring for estimating the value of a target policy using data logged by a different behavior policy.

# %% [markdown]
# ## Planned Coverage
#
# - Off-policy evaluation problem setup.
# - IPS estimators for bandit data.
# - Identification assumptions and diagnostics.
# - Bias, variance, and practical interpretation.
