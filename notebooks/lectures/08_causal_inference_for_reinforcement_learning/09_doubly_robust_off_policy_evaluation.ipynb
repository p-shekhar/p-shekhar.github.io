# %% [markdown]
# # 09. Doubly Robust Off-Policy Evaluation
#
# Draft lecture notebook.
#
# This notebook will combine outcome models with propensity weighting to create more stable off-policy evaluation estimators.

# %% [markdown]
# ## Planned Coverage
#
# - Outcome modeling for rewards.
# - Doubly robust OPE intuition.
# - Cross-fitting and model diagnostics.
# - Comparing IPS, direct method, and doubly robust estimates.
