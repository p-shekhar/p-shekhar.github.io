# %% [markdown]
# # 18. Offline RL Dataset Quality and Extrapolation Risk
#
# Draft lecture notebook.
#
# This notebook will evaluate dataset coverage, support mismatch, extrapolation error, and conservative policy improvement in offline RL.

# %% [markdown]
# ## Planned Coverage
#
# - Offline RL dataset audits.
# - Coverage, support mismatch, and extrapolation error.
# - Conservative policy improvement.
# - Diagnostics before policy deployment.
