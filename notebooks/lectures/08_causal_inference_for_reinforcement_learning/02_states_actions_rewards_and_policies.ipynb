# %% [markdown]
# # 02. States, Actions, Rewards, and Policies
#
# Draft lecture notebook.
#
# This notebook will teach core RL vocabulary from scratch for causal inference learners: state, action, reward, policy, trajectory, horizon, and value.

# %% [markdown]
# ## Planned Coverage
#
# - State, action, reward, policy, and trajectory definitions.
# - Static treatment rules versus sequential policies.
# - Short-horizon and long-horizon examples.
# - Mapping familiar causal concepts onto RL notation.
