# %% [markdown]
# # 01. RL as a Sequential Causal System
#
# Draft lecture notebook.
#
# This notebook will introduce reinforcement learning through causal language: policies intervene over time, actions affect future states, rewards, users, and the data that will be observed later.

# %% [markdown]
# ## Planned Coverage
#
# - RL as repeated causal decision-making.
# - Actions, future states, rewards, and feedback loops.
# - Why sequential decisions are different from one-shot treatments.
# - Examples from recommendations, pricing, support routing, and agents.
