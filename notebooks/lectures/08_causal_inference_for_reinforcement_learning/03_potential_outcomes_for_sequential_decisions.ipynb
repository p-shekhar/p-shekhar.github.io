# %% [markdown]
# # 03. Potential Outcomes for Sequential Decisions
#
# Draft lecture notebook.
#
# This notebook will extend potential outcomes from one-time treatments to treatment sequences, dynamic regimes, and counterfactual trajectories.

# %% [markdown]
# ## Planned Coverage
#
# - Potential outcomes under action sequences.
# - Dynamic treatment regimes and policy-specific outcomes.
# - Counterfactual trajectories.
# - Sequential consistency and exchangeability intuition.
