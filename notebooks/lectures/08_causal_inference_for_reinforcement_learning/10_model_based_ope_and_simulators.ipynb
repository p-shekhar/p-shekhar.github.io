# %% [markdown]
# # 10. Model-Based OPE and Simulators
#
# Draft lecture notebook.
#
# This notebook will evaluate policies using transition models, reward models, and simulators, while emphasizing the risks of model misspecification.

# %% [markdown]
# ## Planned Coverage
#
# - Direct model-based policy evaluation.
# - Reward models, transition models, and simulators.
# - Simulator validation and misspecification risk.
# - When simulation supports decisions and when it misleads.
