# %% [markdown]
# # 13. Dynamic Treatment Regimes and the G-Formula
#
# Draft lecture notebook.
#
# This notebook will connect dynamic treatment regimes from causal inference to RL-style policies, the g-formula, and sequential exchangeability.

# %% [markdown]
# ## Planned Coverage
#
# - Dynamic treatment regimes.
# - Sequential exchangeability, positivity, and consistency.
# - The g-formula for policy value.
# - Healthcare, education, and product examples.
