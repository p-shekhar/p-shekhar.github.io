# %% [markdown]
# # 16. Confounded Bandits and Observational RL
#
# Draft lecture notebook.
#
# This notebook will show what goes wrong when actions were not randomized, propensities are unknown, or historical policies used hidden information.

# %% [markdown]
# ## Planned Coverage
#
# - Confounded action assignment.
# - Hidden logging-policy features and unknown propensities.
# - Selection bias in offline RL datasets.
# - Sensitivity analysis and design remedies.
