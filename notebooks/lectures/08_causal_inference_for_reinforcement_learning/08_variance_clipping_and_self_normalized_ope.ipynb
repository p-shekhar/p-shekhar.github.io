# %% [markdown]
# # 08. Variance, Clipping, and Self-Normalized OPE
#
# Draft lecture notebook.
#
# This notebook will diagnose weight explosion in off-policy evaluation and compare clipping, self-normalization, and other bias-variance tradeoffs.

# %% [markdown]
# ## Planned Coverage
#
# - Importance weight instability.
# - Effective sample size and support diagnostics.
# - Weight clipping and self-normalized IPS.
# - Bias-variance tradeoffs in deployment decisions.
