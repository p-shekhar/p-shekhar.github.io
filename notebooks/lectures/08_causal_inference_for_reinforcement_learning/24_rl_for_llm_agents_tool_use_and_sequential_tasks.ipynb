# %% [markdown]
# # 24. RL for LLM Agents, Tool Use, and Sequential Tasks
#
# Draft lecture notebook.
#
# This notebook will treat LLM agents as sequential decision systems that choose tools, plan steps, use memory, retry actions, hand off tasks, and optimize task-level rewards.

# %% [markdown]
# ## Planned Coverage
#
# - LLM agents as policies over actions and tools.
# - Tool-use decisions, planning, retries, and handoffs.
# - Task-level rewards and intermediate outcomes.
# - Causal evaluation of agent training and deployment changes.
