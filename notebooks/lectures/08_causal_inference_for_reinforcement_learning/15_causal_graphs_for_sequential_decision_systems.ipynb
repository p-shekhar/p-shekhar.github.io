# %% [markdown]
# # 15. Causal Graphs for Sequential Decision Systems
#
# Draft lecture notebook.
#
# This notebook will use DAGs, time-indexed graphs, and single-world intervention graphs to reason about sequential decision systems.

# %% [markdown]
# ## Planned Coverage
#
# - Time-indexed causal graphs.
# - Actions, states, rewards, and unobserved variables.
# - SWIG intuition for sequential interventions.
# - Graph-based diagnosis of confounding and bad controls.
