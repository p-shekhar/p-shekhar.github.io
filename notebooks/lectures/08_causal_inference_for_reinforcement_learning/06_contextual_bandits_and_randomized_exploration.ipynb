# %% [markdown]
# # 06. Contextual Bandits and Randomized Exploration
#
# Draft lecture notebook.
#
# This notebook will treat exploration as experimental design and introduce epsilon-greedy, Thompson sampling, UCB, and randomized policy variation for causal identification.

# %% [markdown]
# ## Planned Coverage
#
# - Contextual bandit setup.
# - Exploration, exploitation, and identification.
# - Epsilon-greedy, Thompson sampling, and UCB intuition.
# - Logging randomized exploration for future evaluation.
