# %% [markdown]
# # 12. Policy Learning from Observational and Logged Data
#
# Draft lecture notebook.
#
# This notebook will learn improved policies from historical data while making the identification assumptions and extrapolation risks explicit.

# %% [markdown]
# ## Planned Coverage
#
# - Policy learning as causal decision optimization.
# - Learning from randomized, logged, and observational data.
# - Policy class restrictions and interpretability.
# - Offline policy selection with diagnostics.
