# %% [markdown]
# # 22. Interference, Multi-Agent Systems, and Spillovers
#
# Draft lecture notebook.
#
# This notebook will study multi-agent environments, marketplaces, recommender systems, and spillovers where one policy's actions affect other users or agents.

# %% [markdown]
# ## Planned Coverage
#
# - Interference in sequential decision systems.
# - Multi-agent and marketplace dynamics.
# - Spillovers in recommendations and platform policies.
# - Designs for measuring policy effects with interference.
