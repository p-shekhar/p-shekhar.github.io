# %% [markdown]
# # 05. Decoding Parameters, Temperature, Top-p, and Output Variability
#
# Draft lecture notebook.
#
# This notebook will evaluate the causal effects of temperature, top-p, max tokens, sampling policies, and deterministic versus stochastic generation.

# %% [markdown]
# ## Planned Coverage
#
# - Decoding settings as interventions.
# - Output variability and repeated-generation designs.
# - Quality, creativity, factuality, and safety outcomes.
# - Variance, reproducibility, and decision risk.
