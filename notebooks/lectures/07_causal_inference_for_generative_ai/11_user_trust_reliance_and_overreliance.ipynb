# %% [markdown]
# # 11. User Trust, Reliance, and Overreliance
#
# Draft lecture notebook.
#
# This notebook will measure how generated answers change user trust, reliance, calibration, verification behavior, and decision quality.

# %% [markdown]
# ## Planned Coverage
#
# - Trust and reliance as causal outcomes.
# - Overreliance, underreliance, and verification behavior.
# - Experimental designs for measuring user calibration.
# - Human decision quality downstream of generated content.
