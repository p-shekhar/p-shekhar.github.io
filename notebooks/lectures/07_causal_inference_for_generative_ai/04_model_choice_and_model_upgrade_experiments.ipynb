# %% [markdown]
# # 04. Model Choice and Model Upgrade Experiments
#
# Draft lecture notebook.
#
# This notebook will compare models, model versions, fine-tuned models, distillation, quantization, and routing strategies as causal interventions.

# %% [markdown]
# ## Planned Coverage
#
# - Model choice and upgrade treatments.
# - Online experiments for model versions.
# - Heterogeneous effects by task, user, and prompt type.
# - Quality, cost, latency, and safety tradeoffs.
