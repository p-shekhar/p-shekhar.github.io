# %% [markdown]
# # 01. Generative AI as a Causal System
#
# Draft lecture notebook.
#
# This notebook will frame generative AI as a causal system that changes users, creators, workflows, decisions, content ecosystems, and downstream data.

# %% [markdown]
# ## Planned Coverage
#
# - Generative AI outputs as interventions.
# - Users, creators, workers, and platforms as affected units.
# - Generated content, behavior change, and downstream data feedback.
# - Why GenAI evaluation needs causal estimands.
