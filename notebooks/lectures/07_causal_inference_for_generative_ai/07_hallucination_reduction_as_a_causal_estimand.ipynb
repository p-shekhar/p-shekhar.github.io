# %% [markdown]
# # 07. Hallucination Reduction as a Causal Estimand
#
# Draft lecture notebook.
#
# This notebook will define and estimate causal effects on hallucination, unsupported claims, factuality, citation correctness, and downstream user harm.

# %% [markdown]
# ## Planned Coverage
#
# - Hallucination and unsupported claims as outcomes.
# - Treatment definitions for hallucination-reduction interventions.
# - Measurement, annotation, and audit samples.
# - Connecting factuality improvements to user and business outcomes.
