# %% [markdown]
# # 13. Code Generation and Developer Productivity
#
# Draft lecture notebook.
#
# This notebook will causally evaluate coding assistants using completion acceptance, time saved, bug rates, review quality, maintainability, and developer learning.

# %% [markdown]
# ## Planned Coverage
#
# - Coding assistant interventions.
# - Productivity, quality, security, and maintenance outcomes.
# - Randomized and observational designs for developer tools.
# - Interpreting short-run speed versus long-run code quality.
