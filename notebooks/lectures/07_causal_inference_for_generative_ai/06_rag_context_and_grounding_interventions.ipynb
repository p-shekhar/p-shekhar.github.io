# %% [markdown]
# # 06. RAG, Context, and Grounding Interventions
#
# Draft lecture notebook.
#
# This notebook will estimate the effect of retrieval, grounding documents, citations, context length, reranking, and chunking on generated outputs and downstream outcomes.

# %% [markdown]
# ## Planned Coverage
#
# - Retrieval and grounding as treatments.
# - Context-window and citation interventions.
# - Retrieval diagnostics as post-treatment variables.
# - Outcome measures for factuality, usefulness, trust, and task success.
