# %% [markdown]
# # 12. Human Creativity, Productivity, and Quality Effects
#
# Draft lecture notebook.
#
# This notebook will evaluate GenAI effects on writing, design, coding, analysis, support work, creative workflows, productivity, and quality.

# %% [markdown]
# ## Planned Coverage
#
# - Productivity and quality estimands.
# - Human-AI collaboration designs.
# - Heterogeneity by skill, task, and workflow.
# - Measuring speed, originality, correctness, and satisfaction.
