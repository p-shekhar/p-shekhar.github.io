# %% [markdown]
# # 14. Synthetic Data Generation and Causal Validity
#
# Draft lecture notebook.
#
# This notebook will examine when synthetic data helps or hurts causal analysis, including distribution shift, privacy, representativeness, and downstream estimator bias.

# %% [markdown]
# ## Planned Coverage
#
# - Synthetic data as generated evidence and as an intervention.
# - Privacy, representativeness, and bias tradeoffs.
# - Estimator behavior under synthetic-data distortions.
# - Validation strategies before using synthetic data causally.
