# %% [markdown]
# # 09. Preference Data and Causal Interpretation
#
# Draft lecture notebook.
#
# This notebook will study pairwise preferences, RLHF-style data, selection bias, annotator heterogeneity, and how to interpret preference wins causally.

# %% [markdown]
# ## Planned Coverage
#
# - Preference labels as outcomes and training signals.
# - Pairwise comparisons and selection bias.
# - Annotator heterogeneity and context effects.
# - Preference wins versus real-world impact.
