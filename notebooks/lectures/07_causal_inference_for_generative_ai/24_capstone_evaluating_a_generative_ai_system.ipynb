# %% [markdown]
# # 24. Capstone: Evaluating a Generative AI System
#
# Draft lecture notebook.
#
# This notebook will complete an end-to-end GenAI evaluation: define the estimand, design the experiment or logs, measure quality and safety, estimate impact, diagnose risks, and write the memo.

# %% [markdown]
# ## Planned Coverage
#
# - End-to-end causal evaluation of a generative AI system.
# - Estimand, logging, measurement, design, estimation, and diagnostics.
# - Quality, safety, cost, latency, trust, and productivity outcomes.
# - Portfolio-ready final memo and governance artifact.
