# %% [markdown]
# # 08. LLM Judges, Human Labels, and Measurement Error
#
# Draft lecture notebook.
#
# This notebook will examine human labels, LLM judges, rubrics, annotation bias, calibration, and differential measurement error in GenAI evaluation.

# %% [markdown]
# ## Planned Coverage
#
# - Human and AI judges as measurement systems.
# - Rubric design, calibration, and audit sampling.
# - Differential measurement error across treatment arms.
# - Designs that separate real improvement from judge artifacts.
