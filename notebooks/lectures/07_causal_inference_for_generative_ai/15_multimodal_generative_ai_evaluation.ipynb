# %% [markdown]
# # 15. Multimodal Generative AI Evaluation
#
# Draft lecture notebook.
#
# This notebook will extend causal evaluation to image, audio, video, document understanding, and multimodal output quality.

# %% [markdown]
# ## Planned Coverage
#
# - Multimodal generation as treatment and outcome.
# - Image, audio, video, and document workflows.
# - Human and automated quality measurement.
# - Safety, accessibility, and downstream task outcomes.
