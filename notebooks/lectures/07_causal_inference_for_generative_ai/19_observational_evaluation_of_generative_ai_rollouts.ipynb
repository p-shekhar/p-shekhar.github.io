# %% [markdown]
# # 19. Observational Evaluation of Generative AI Rollouts
#
# Draft lecture notebook.
#
# This notebook will evaluate non-randomized GenAI launches using adjustment, matching, difference-in-differences, synthetic control, and sensitivity analysis.

# %% [markdown]
# ## Planned Coverage
#
# - Non-randomized GenAI adoption and rollout settings.
# - Confounding, selection bias, and adoption timing.
# - Adjustment, DiD, synthetic control, and sensitivity analysis.
# - Credibility checks for observational GenAI evidence.
