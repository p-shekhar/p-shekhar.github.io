# %% [markdown]
# # 02. Estimands for Generative AI Changes
#
# Draft lecture notebook.
#
# This notebook will define estimands for generative AI changes by specifying treatment, outcome, unit, exposure, prompt, model, decoding policy, context, and time window.

# %% [markdown]
# ## Planned Coverage
#
# - Treatment definitions for prompts, models, tools, policies, and context.
# - Generated outputs as intermediate objects.
# - Outcome windows and affected populations.
# - Estimand templates for GenAI product evaluations.
